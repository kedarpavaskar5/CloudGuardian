# %% [markdown]
# # Week3_CloudGuardian
# Template notebook.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Paths

# %%
from pathlib import Path

# %% [markdown]
# ## Load Data

# %%
# load baseline/misconfig/remediation outputs

# %% [markdown]
# ## Crosswalk

# %%
# ISO27001 / DPDP / HIPAA mapping

# %% [markdown]
# ## Comparison

# %%
# before vs after

# %% [markdown]
# ## Visualizations

# %%
# charts

# %% [markdown]
# ## Export

# %%
# csv + markdown
